# %%
import pandas as pd
df = pd.read_csv("data_nilai_siswa.csv")
df
# Out:
#      Nama  Inggris  Matematika  Pemrograman
# 0     Ani       83          65           89
# 1    Budi       47          85           88
# 2   Citra       90          51           48
# 3    Dewi       57          58           61
# 4     Eka       87          96           99
# ..    ...      ...         ...          ...
# 95    Uli       85          79           65
# 96    Via       68          82           91
# 97  Wulan       66          71           81
# 98  Yusuf       80          89           76
# 99   Zara       59          80           77
#
# [100 rows x 4 columns]

# %%
df.shape
# Out:
# (100, 4)

# %%
df.dtypes
# Out:
# Nama           object
# Inggris         int64
# Matematika      int64
# Pemrograman     int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Nama', 'Inggris', 'Matematika', 'Pemrograman'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nama         100 non-null    object
#  1   Inggris      100 non-null    int64
#  2   Matematika   100 non-null    int64
#  3   Pemrograman  100 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 3.3+ KB

# %%
df.describe()
# Out:
#           Inggris  Matematika  Pemrograman
# count  100.000000  100.000000   100.000000
# mean    70.630000   75.500000    72.410000
# std     15.100776   12.593489    14.752569
# min     41.000000   38.000000    42.000000
# 25%     58.750000   66.000000    60.750000
# 50%     70.000000   77.000000    73.500000
# 75%     84.000000   84.000000    83.500000
# max     96.000000   99.000000    99.000000

# %%
df.isna().sum()
# Out:
# Nama           0
# Inggris        0
# Matematika     0
# Pemrograman    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.tail()
# Out:
#      Nama  Inggris  Matematika  Pemrograman
# 95    Uli       85          79           65
# 96    Via       68          82           91
# 97  Wulan       66          71           81
# 98  Yusuf       80          89           76
# 99   Zara       59          80           77

# %%
df.head()
# Out:
#     Nama  Inggris  Matematika  Pemrograman
# 0    Ani       83          65           89
# 1   Budi       47          85           88
# 2  Citra       90          51           48
# 3   Dewi       57          58           61
# 4    Eka       87          96           99

# %%
df.sample(5, random_state=42)
# Out:
#      Nama  Inggris  Matematika  Pemrograman
# 83   Imam       56          62           61
# 53   Dewi       91          87           96
# 70   Udin       72          83           55
# 45    Uli       59          52           95
# 44  Tegar       94          84           77
